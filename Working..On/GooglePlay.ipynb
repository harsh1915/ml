# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# from google.colab import file

# %%
path="/content/gdrive/MyDrive/ML/DataSets/googleplaystore.csv"

# %%
df=pd.read_csv(path)

# %%
df
#It Prints Our DataFrame
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
df.shape

#It Shows Size of Our DataFrame
# Out:
# (10841, 13)

# %%
df.columns

#It Shows Dolumns Of Our DataFrame
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.describe()

#It Show Howmany Numeric Columns In Our Data Frame
#We Can See There is Only One Columns Whose pure numeric
#Rating Must Be In Between 1-5 But here We Can see Max Value is 19 We have to hande it.
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.dtypes

#It Shows Data Types Of Every Columns
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.info()

#It Show Numbers Of Columns Data Types Of Columns ans No Null Count Of Every Column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
# df.isna().sum()
df.isnull().sum()

# It Shows NaN Values In Every Columns
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df1=df.copy()
df1=df1.drop(columns=['Content Rating','Genres'],axis=1)

# %%
df1['Rating'].unique()
# df1.Rating.unique().sum()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df1['Rating']=df1['Rating'].fillna(df1['Rating'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# App             0
# Category        0
# Rating          0
# Reviews         0
# Size            0
# Installs        0
# Type            1
# Price           0
# Last Updated    0
# Current Ver     8
# Android Ver     3
# dtype: int64

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Last Updated', 'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df1.Type.unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df1
# Out:
#                                                      App  ...         Android Ver
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ...        4.0.3 and up
# 1                                    Coloring book moana  ...        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint  ...          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book  ...          4.4 and up
# ...                                                  ...  ...                 ...
# 10836                                   Sya9a Maroc - FR  ...          4.1 and up
# 10837                   Fr. Mike Schmitz Audio Teachings  ...          4.1 and up
# 10838                             Parkinson Exercices FR  ...          2.2 and up
# 10839                      The SCP Foundation DB fr nn5n  ...  Varies with device
# ...

# %%
df1=df1.drop(df1.loc[df1.Type.isna()].index.tolist())

# %%
df1.shape
# Out:
# (10840, 11)

# %%
df1.isna().sum()
# Out:
# App             0
# Category        0
# Rating          0
# Reviews         0
# Size            0
# Installs        0
# Type            0
# Price           0
# Last Updated    0
# Current Ver     8
# Android Ver     3
# dtype: int64

# %%
df1.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Last Updated', 'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df1=df1.drop(df1[df1['Price']=='Everyone'].index.tolist())

# %%
df1.shape
# Out:
# (10839, 11)

# %%
df1.isnull().sum()
# Out:
# App             0
# Category        0
# Rating          0
# Reviews         0
# Size            0
# Installs        0
# Type            0
# Price           0
# Last Updated    0
# Current Ver     8
# Android Ver     2
# dtype: int64

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Last Updated', 'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Last Updated', 'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
# df1=df1.reindex(columns=df1.columns.tolist() + ['Amit'])

# df1=df1.drop(columns=['Amit'],axis=1)

# %%
df1.Rating.value_counts()
# Out:
# 4.4    2582
# 4.3    1076
# 4.5    1038
# 4.2     952
# 4.6     823
# 4.1     708
# 4.0     568
# 4.7     499
# 3.9     386
# 3.8     303
# 5.0     274
# 3.7     239
# 4.8     234
# 3.6     174
# 3.5     163
# 3.4     128
# 3.3     102
# 4.9      87
# 3.0      83
# 3.1      69
# 3.2      64
# 2.9      45
# 2.8      42
# 2.6      25
# 2.7      25
# 2.5      21
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      13
# 2.0      12
# 1.7       8
# 2.1       8
# 1.8       8
# 1.6       4
# 1.4       3
# 1.5       3
# 1.2       1
# Name: Rating, dtype: int64

# %%
df1['Price']=df1['Price'].str.replace('$',' ')

# %%
df1['Price'].unique()
# Out:
# array(['0', ' 4.99', ' 3.99', ' 6.99', ' 1.49', ' 2.99', ' 7.99', ' 5.99',
#        ' 3.49', ' 1.99', ' 9.99', ' 7.49', ' 0.99', ' 9.00', ' 5.49',
#        ' 10.00', ' 24.99', ' 11.99', ' 79.99', ' 16.99', ' 14.99',
#        ' 1.00', ' 29.99', ' 12.99', ' 2.49', ' 10.99', ' 1.50', ' 19.99',
#        ' 15.99', ' 33.99', ' 74.99', ' 39.99', ' 3.95', ' 4.49', ' 1.70',
#        ' 8.99', ' 2.00', ' 3.88', ' 25.99', ' 399.99', ' 17.99',
#        ' 400.00', ' 3.02', ' 1.76', ' 4.84', ' 4.77', ' 1.61', ' 2.50',
#        ' 1.59', ' 6.49', ' 1.29', ' 5.00', ' 13.99', ' 299.99', ' 379.99',
#        ' 37.99', ' 18.99', ' 389.99', ' 19.90', ' 8.49', ' 1.75',
#        ' 14.00', ' 4.85', ' 46.99', ' 109.99', ' 154.99', ' 3.08',
#        ' 2.59', ' 4.80', ' 1.96', ' 19.40', ' 3.90', ' 4.59', ' 15.46',
#        ' 3.04', ' 4.29', ' 2.60', ' 3.28', ' 4.60', ' 28.99', ' 2.95',
#        ' 2.90', ' 1.97', ' 200.00', ' 89.99', ' 2.56', ' 30.99', ' 3.61',
# ...

# %%
df1['Price']=df1['Price'].astype(float)

# %%
df1.dtypes
# Out:
# App              object
# Category         object
# Rating          float64
# Reviews          object
# Size             object
# Installs         object
# Type             object
# Price           float64
# Last Updated     object
# Current Ver      object
# Android Ver      object
# dtype: object

# %%
# df1.describe()
print(df1.describe().__doc__)
# Out:
#     Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
#     Data structure also contains labeled axes (rows and columns).
#     Arithmetic operations align on both row and column labels. Can be
#     thought of as a dict-like container for Series objects. The primary
#     pandas data structure.
#
#     Parameters
#     ----------
#     data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#         Dict can contain Series, arrays, constants, or list-like objects.
#
#         .. versionchanged:: 0.23.0
#            If data is a dict, column order follows insertion-order for
#            Python 3.6 and later.
#
#         .. versionchanged:: 0.25.0
#            If data is a list of dicts, column order follows insertion-order
#            for Python 3.6 and later.
#
#     index : Index or array-like
#         Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
list2=df1.loc[4:10,'App']

# %%
df1.iloc[:100,:2]
# Out:
#                                                   App           Category
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
# [100 rows x 2 columns]

# %%
list2.shape[0]
# Out:
# 7

# %%
list2.index.tolist()
# Out:
# [4, 5, 6, 7, 8, 9, 10]

# %%
list2.append(df1.loc[10:21,"App"])
# Out:
# 4               Pixel Draw - Number Art Coloring Book
# 5                          Paper flowers instructions
# 6             Smoke Effect Photo Maker - Smoke Editor
# 7                                    Infinite Painter
# 8                                Garden Coloring Book
# 9                       Kids Paint Free - Drawing Fun
# 10                            Text on Photo - Fonteee
# 10                            Text on Photo - Fonteee
# 11            Name Art Photo Editor - Focus n Filters
# 12                     Tattoo Name On My Photo Editor
# 13                              Mandala Coloring Book
# 14    3D Color Pixel by Number - Sandbox Art Coloring
# 15                    Learn To Draw Kawaii Characters
# 16       Photo Designer - Write your name with shapes
# 17                           350 Diy Room Decor Ideas
# 18                      FlipaClip - Cartoon animation
# 19                                       ibis Paint X
# ...

# %%
df1.nlargest(10,'Price')
# Out:
#                                  App   Category  ...  Current Ver   Android Ver
# 4367        I'm Rich - Trump Edition  LIFESTYLE  ...        1.0.1    4.1 and up
# 4197          most expensive app (H)     FAMILY  ...          1.0    7.0 and up
# 4362                      💎 I'm rich  LIFESTYLE  ...        1.0.0    4.4 and up
# 5351                       I am rich  LIFESTYLE  ...          2.0  4.0.3 and up
# 5354                  I am Rich Plus     FAMILY  ...          3.0    4.4 and up
# 5356               I Am Rich Premium    FINANCE  ...          1.6    4.0 and up
# 5358                      I am Rich!    FINANCE  ...          1.0    4.1 and up
# 5359              I am rich(premium)    FINANCE  ...          3.4    4.4 and up
# 5362                   I Am Rich Pro     FAMILY  ...         1.54    1.6 and up
# 5364  I am rich (Most expensive app)    FINANCE  ...            2  4.0.3 and up
#
# [10 rows x 11 columns]

# %%
df1.nsmallest(15,'Price')
# Out:
#                                                   App  ...   Android Ver
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ...  4.0.3 and up
# 1                                 Coloring book moana  ...  4.0.3 and up
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ...  4.0.3 and up
# 3                               Sketch - Draw & Paint  ...    4.2 and up
# 4               Pixel Draw - Number Art Coloring Book  ...    4.4 and up
# 5                          Paper flowers instructions  ...    2.3 and up
# 6             Smoke Effect Photo Maker - Smoke Editor  ...  4.0.3 and up
# 7                                    Infinite Painter  ...    4.2 and up
# 8                                Garden Coloring Book  ...    3.0 and up
# 9                       Kids Paint Free - Drawing Fun  ...  4.0.3 and up
# 10                            Text on Photo - Fonteee  ...    4.1 and up
# 11            Name Art Photo Editor - Focus n Filters  ...    4.0 and up
# ...

# %%
df1['Rating']=df1['Rating'].astype(float)

# %%
# df1.nsmallest(15,'Rating')
df1.nlargest(15,'Rating')
# Out:
#                                              App  ...   Android Ver
# 329                 Hojiboy Tojiboyev Life Hacks  ...  4.0.3 and up
# 612                American Girls Mobile Numbers  ...  4.0.3 and up
# 615                                 Awake Dating  ...    4.4 and up
# 633                        Spine- The dating app  ...  4.0.3 and up
# 636   Girls Live Talk - Free Text and Video Chat  ...  4.0.3 and up
# 640                      Online Girls Chat Group  ...  4.0.3 and up
# 654              Speeding Joyride & Car Meet App  ...    4.1 and up
# 1028                            SUMMER SONIC app  ...    4.4 and up
# 1030                                  Prosperity  ...    2.0 and up
# 1038                   Mindvalley U Tallinn 2018  ...    4.4 and up
# 1547                                Eternal life  ...    1.6 and up
# 2262    Super Hearing Secret Voices Recorder PRO  ...    4.1 and up
# 2271                              FHR 5-Tier 2.0  ...    4.0 and up
# ...

# %%
df1[df1['Rating']==5]
# Out:
#                                               App  ...   Android Ver
# 329                  Hojiboy Tojiboyev Life Hacks  ...  4.0.3 and up
# 612                 American Girls Mobile Numbers  ...  4.0.3 and up
# 615                                  Awake Dating  ...    4.4 and up
# 633                         Spine- The dating app  ...  4.0.3 and up
# 636    Girls Live Talk - Free Text and Video Chat  ...  4.0.3 and up
# ...                                           ...  ...           ...
# 10721                           Mad Dash Fo' Cash  ...    4.1 and up
# 10742                       GKPB FP Online Church  ...    4.4 and up
# 10776                            Monster Ride Pro  ...    2.3 and up
# 10820                             Fr. Daoud Lamei  ...    4.1 and up
# 10837            Fr. Mike Schmitz Audio Teachings  ...    4.1 and up
#
# [274 rows x 11 columns]
