# %%
model_path='/content/drive/MyDrive/ML/Regression/cancer_model.sav'

# %%
import pickle

# %%
load_model=pickle.load(open(model_path,'rb'))

# %%
import pandas as pd

# %%
path='/content/drive/MyDrive/ML/Regression/mydf.csv'

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#    mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0       500.00         50.12  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
result=load_model.predict(df)
result
# Out:
# array([1, 0, 0, 1, 0])
