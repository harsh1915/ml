# %% [markdown]
# ## import pandas as pd

# %% [markdown]
# <h4> Read Date From json file</h4>

# %%
jdf = pd.read_json(r"mystd.json")
print(jdf)
# Out:
#     _id   Age    Dept  Gender      Name    Salary  \
# 0     1  21.0     BCA    Male    Krunal     750.0
# 1     2  23.0     MCA    Male   Nishant    1000.0
# 2     3  25.0    BCOM    Male     Karan     500.0
# 3     4  29.0     BBA    Male     Harsh    1500.0
# 4     5  30.0  BPHARM    Male      Anas     600.0
# 5     6  19.0      BE    Male    Chirag    1000.0
# 6     7  23.0      ME  Female    Vishwa    5000.0
# 7     8  25.0     BBA  Female  Shraddha     400.0
# 8     9  24.0     BCA  Female    Drasti    4000.0
# 9    10  23.0     MCA  Female     Jinal    5000.0
# 10   11  22.0    BCOM  Female    Roshni     500.0
# 11   12  22.0     BBA    Male    Mrudul    1000.0
# 12   13  40.0  BPHARM    Male     Anjit     500.0
# 13   14  36.0      BE    Male   Priyank     800.0
# 14   15  25.0      ME    Male     Nitin    1000.0
# 15   16  27.0     BBA    Male   Bhautik    6000.0
# 16   17  21.0     BCA  Female     Aarti    2000.0
# 17   18  21.0     MCA  Female     Divya    4000.0
# ...

# %% [markdown]
# <h4> second way to Read Date From json file</h4>

# %%
import json

# %%
with open('mystd.json','r') as js:
    jdata = js.read()
loadjson  = json.loads(jdata)

# %%
loadjson
# Out:
# [{'_id': 1,
#   'Age': 21,
#   'Dept': 'BCA',
#   'Gender': 'Male',
#   'Name': 'Krunal',
#   'Salary': 750},
#  {'_id': 2,
#   'Age': 23,
#   'Dept': 'MCA',
#   'Gender': 'Male',
#   'Name': 'Nishant',
#   'Salary': 1000},
#  {'_id': 3,
#   'Age': 25,
#   'Dept': 'BCOM',
#   'Gender': 'Male',
#   'Name': 'Karan',
#   'Salary': 500},
#  {'_id': 4,
#   'Age': 29,
#   'Dept': 'BBA',
#   'Gender': 'Male',
#   'Name': 'Harsh',
#   'Salary': 1500},
#  {'_id': 5,
#   'Age': 30,
#   'Dept': 'BPHARM',
#   'Gender': 'Male',
#   'Name': 'Anas',
#   'Salary': 600},
#  {'_id': 6,
#   'Age': 19,
#   'Dept': 'BE',
#   'Gender': 'Male',
#   'Name': 'Chirag',
#   'Salary': 1000},
#  {'_id': 7,
#   'Age': 23,
#   'Dept': 'ME',
#   'Gender': 'Female',
#   'Name': 'Vishwa',
#   'Salary': 5000},
#  {'_id': 8,
#   'Age': 25,
#   'Dept': 'BBA',
#   'Gender': 'Female',
#   'Name': 'Shraddha',
#   'Salary': 400},
#  {'_id': 9,
#   'Age': 24,
#   'Dept': 'BCA',
#   'Gender': 'Female',
#   'Name': 'Drasti',
# ...

# %%
print(type(loadjson))
# Out:
# <class 'list'>

# %%
jdf2 = pd.DataFrame(loadjson)

# %%
jdf2
# Out:
#     _id   Age    Dept  Gender      Name    Salary  \
# 0     1  21.0     BCA    Male    Krunal     750.0
# 1     2  23.0     MCA    Male   Nishant    1000.0
# 2     3  25.0    BCOM    Male     Karan     500.0
# 3     4  29.0     BBA    Male     Harsh    1500.0
# 4     5  30.0  BPHARM    Male      Anas     600.0
# 5     6  19.0      BE    Male    Chirag    1000.0
# 6     7  23.0      ME  Female    Vishwa    5000.0
# 7     8  25.0     BBA  Female  Shraddha     400.0
# 8     9  24.0     BCA  Female    Drasti    4000.0
# 9    10  23.0     MCA  Female     Jinal    5000.0
# 10   11  22.0    BCOM  Female    Roshni     500.0
# 11   12  22.0     BBA    Male    Mrudul    1000.0
# 12   13  40.0  BPHARM    Male     Anjit     500.0
# 13   14  36.0      BE    Male   Priyank     800.0
# 14   15  25.0      ME    Male     Nitin    1000.0
# 15   16  27.0     BBA    Male   Bhautik    6000.0
# 16   17  21.0     BCA  Female     Aarti    2000.0
# 17   18  21.0     MCA  Female     Divya    4000.0
# ...
